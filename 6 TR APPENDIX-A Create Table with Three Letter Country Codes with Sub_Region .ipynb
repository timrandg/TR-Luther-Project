# %%
import pandas
countries = pandas.read_csv('country_data.csv')
countries_short = countries[['alpha-3','sub-region']]
countries_short.columns = ['COUNTRY', 'SUB_REGION']
countries_short.to_pickle("./countries_three_continent.pkl")

# %%
# !pwd
# Out:
# /Users/loaner/ds/GITHUB_REPOS/sf18_ds12/projects/02-luther/TR_web_scrape_country

# %%
re_imported = pandas.read_pickle("./countries_three_continent.pkl")

# %%
re_imported
# Out:
#     COUNTRY                       SUB_REGION
# 0       AFG                    Southern Asia
# 1       ALA                  Northern Europe
# 2       ALB                  Southern Europe
# 3       DZA                  Northern Africa
# 4       ASM                        Polynesia
# 5       AND                  Southern Europe
# 6       AGO               Sub-Saharan Africa
# 7       AIA  Latin America and the Caribbean
# 8       ATA                              NaN
# 9       ATG  Latin America and the Caribbean
# 10      ARG  Latin America and the Caribbean
# 11      ARM                     Western Asia
# 12      ABW  Latin America and the Caribbean
# 13      AUS        Australia and New Zealand
# 14      AUT                   Western Europe
# 15      AZE                     Western Asia
# 16      BHS  Latin America and the Caribbean
# 17      BHR                     Western Asia
# 18      BGD                    Southern Asia
# 19      BRB  Latin America and the Caribbean
# ...

# %%
set(re_imported.SUB_REGION)
# Out:
# {'Australia and New Zealand',
#  'Central Asia',
#  'Eastern Asia',
#  'Eastern Europe',
#  'Latin America and the Caribbean',
#  'Melanesia',
#  'Micronesia',
#  'Northern Africa',
#  'Northern America',
#  'Northern Europe',
#  'Polynesia',
#  'South-eastern Asia',
#  'Southern Asia',
#  'Southern Europe',
#  'Sub-Saharan Africa',
#  'Western Asia',
#  'Western Europe',
#  nan}
